# %% [markdown]
# 요즘은 잎 노드로 표기함 단말노드는 옛날 말 간선 엣지라는 게 있음
# 부모와 자식 노드를 연결함
# 트리에서는 아래로 쭉쭈 ㄱ그려나가다가
# 맨 끝에 보면 잎이 있음
# 루트를 따라 올라가는 노드 모두 조상 노드라고 함
# H 조상은 D,A A는 가장 위에있어서 조상이 없음
# 오...
# 부모와 연결된 간선을 끊으면 서브 트리가 생성된다
# 차수를 가지고 기본적으로 설명할 수 있ㅇㅁ
